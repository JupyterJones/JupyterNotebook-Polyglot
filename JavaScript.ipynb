// %% [markdown]
// # Python commands

// %%
%%writefile StartJavascriptNotebook.sh
#!/bin/sh
export PATH=$PATH:/opt/pkgconfig/bin
export PKG_CONFIG_PATH=/usr/local/lib/pkgconfig/
ijs
// Out:
// Writing StartJavascriptNotebook.sh

// %%
!chmod +x StartJavascriptNotebook.sh

// %% [markdown]
// # -------- END Python Commands -----------

// %% [markdown]
// # jinja2==2.9

// %%
var msg = ["Hello", "World!"].join(", ");
console.log(msg);
// Out:
// Hello, World!
// undefined

// %%
var y = { a:3, b:'four', c: false };
console.log(y);
// Out:
// { a: 3, b: 'four', c: false }
// undefined

// %%
var data = [];
for (var i = 0; i < 10; i++) {
    var x = 2*Math.PI * i/ 360;
    var obj = {
      x: x,
      i: i,
      sin: Math.sin(x),
      cos: Math.cos(x),
      tan: Math.tan(x)
    };
    console.log(data);
    data.push(obj);
}
// Out:
// []
// [ { x: 0, i: 0, sin: 0, cos: 1, tan: 0 } ]
// [ { x: 0, i: 0, sin: 0, cos: 1, tan: 0 },
//   { x: 0.017453292519943295,
//     i: 1,
//     sin: 0.01745240643728351,
//     cos: 0.9998476951563913,
//     tan: 0.017455064928217585 } ]
// [ { x: 0, i: 0, sin: 0, cos: 1, tan: 0 },
//   { x: 0.017453292519943295,
//     i: 1,
//     sin: 0.01745240643728351,
//     cos: 0.9998476951563913,
//     tan: 0.017455064928217585 },
//   { x: 0.03490658503988659,
//     i: 2,
//     sin: 0.03489949670250097,
//     cos: 0.9993908270190958,
//     tan: 0.03492076949174773 } ]
// [ { x: 0, i: 0, sin: 0, cos: 1, tan: 0 },
//   { x: 0.017453292519943295,
//     i: 1,
//     sin: 0.01745240643728351,
//     cos: 0.9998476951563913,
//     tan: 0.017455064928217585 },
//   { x: 0.03490658503988659,
//     i: 2,
//     sin: 0.03489949670250097,
//     cos: 0.9993908270190958,
//     tan: 0.03492076949174773 },
//   { x: 0.05235987755982988,
//     i: 3,
//     sin: 0.05233595624294383,
// ...
